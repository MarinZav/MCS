# %% [markdown]
# Preprocesamiento de datos

# %%
### importacion de librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import itertools

from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# carga de datos

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('datasets/data.csv')

# %%
# Configura pandas para mostrar el contenido completo de las filas
pd.set_option('display.max_colwidth', None)

# %%
data = data.rename(columns={'jobTitle':'job_title',
                            'perfEval':'perf_eval',
                            'basePay':'base_pay'})

# %%
# creamos una columna nueva con el salario total

data['total_salary'] = data['base_pay'] + data['bonus']

# %%
# función que calcule la categoría de edad

def assing_age_range(age):
    if age < 0 or pd.isna(age):
        return 'NA'
    elif age < 20:
        return '0-19'
    elif age < 40:
        return '20-39'
    elif age < 60:
        return '40-59'
    elif age >= 60:
        return '60+'

# %%
# función que calcule la categoría de ingresos

def total_salary_range(salary):
    if salary < 40000 or pd.isna(salary):
        return '< 40,000'
    elif salary < 80001:
        return '40,000-80,000'
    elif salary < 120001:
        return '80,001-120,000'
    elif salary < 160001:
        return '120,001-160,000'
    elif salary >= 160001:
        return '> 160,000'

# %%
data['total_salary_range'] = data['total_salary'].apply(total_salary_range)
data['age_group'] = data['age'].apply(assing_age_range)

# %%
data.head()
# Out:
#              job_title  gender  age  perf_eval      edu            dept  \
# 0     Graphic Designer  Female   18          5  College      Operations
# 1    Software Engineer    Male   21          5  College      Management
# 2  Warehouse Associate  Female   19          4      PhD  Administration
# 3    Software Engineer    Male   20          5  Masters           Sales
# 4     Graphic Designer    Male   26          5  Masters     Engineering
#
#    seniority  base_pay  bonus  total_salary total_salary_range age_group
# 0          2     42363   9938         52301      40,000-80,000      0-19
# 1          5    108476  11128        119604     80,001-120,000     20-39
# 2          5     90208   9268         99476     80,001-120,000      0-19
# 3          4    108080  10154        118234     80,001-120,000     20-39
# 4          5     99464   9319        108783     80,001-120,000     20-39

# %%
testisng_df = (
    data
    .drop(columns={'age','base_pay','bonus','total_salary'})
)

# %%
testisng_df.head()
# Out:
#              job_title  gender  perf_eval      edu            dept  seniority  \
# 0     Graphic Designer  Female          5  College      Operations          2
# 1    Software Engineer    Male          5  College      Management          5
# 2  Warehouse Associate  Female          4      PhD  Administration          5
# 3    Software Engineer    Male          5  Masters           Sales          4
# 4     Graphic Designer    Male          5  Masters     Engineering          5
#
#   total_salary_range age_group
# 0      40,000-80,000      0-19
# 1     80,001-120,000     20-39
# 2     80,001-120,000      0-19
# 3     80,001-120,000     20-39
# 4     80,001-120,000     20-39

# %%
data = {
    "job_title": ["Graphic Designer", "Software Engineer", "Warehouse Associate", "Software Engineer", "Graphic Designer"],
    "gender": ["Female", "Male", "Female", "Male", "Male"],
    "perf_eval": [5, 5, 4, 5, 5],
    "edu": ["College", "College", "PhD", "Masters", "Masters"],
    "dept": ["Operations", "Management", "Administration", "Sales", "Engineering"],
    "seniority": [2, 5, 5, 4, 5],
    "total_salary_range": ["40,000-80,000", "80,001-120,000", "80,001-120,000", "80,001-120,000", "80,001-120,000"],
    "age_group": ["0-19", "20-39", "0-19", "20-39", "20-39"]
}


def generate_contrast_sets(data, max_level):
    tree = {}

    columns = list(data.keys())

    classes_level_1 = list(set(data[columns[0]]))
    tree[1] = classes_level_1

    for level in range(2, max_level + 1):
        new_level_classes = []
        if level == 2:
            combinations = list(itertools.product(tree[1], set(data[columns[1]])))
        else:
            combinations = generate_combinations(tree[level - 1], set(data[columns[level - 1]]))

        for combination in combinations:
            new_classes = tuple(combination)
            if not any(set(c) == set(new_classes) for c in tree.values()):
                new_level_classes.append(new_classes)

        if new_level_classes:
            tree[level] = new_level_classes
        else:
            break

    return tree

def generate_combinations(previous_level, column_data):
    combinations = []
    for prev_class in previous_level:
        for column_value in column_data:
            new_combination = prev_class + (column_value,)
            if len(set(new_combination)) == len(new_combination):
                combinations.append(new_combination)
    return combinations



max_level = 8

contrast_sets_tree = generate_contrast_sets(data, max_level)

for level, classes in contrast_sets_tree.items():
    print(f'Level {level}: {classes}')
# Out:
# Level 1: ['Graphic Designer', 'Warehouse Associate', 'Software Engineer']
# Level 2: [('Graphic Designer', 'Female'), ('Graphic Designer', 'Male'), ('Warehouse Associate', 'Female'), ('Warehouse Associate', 'Male'), ('Software Engineer', 'Female'), ('Software Engineer', 'Male')]
# Level 3: [('Graphic Designer', 'Female', 4), ('Graphic Designer', 'Female', 5), ('Graphic Designer', 'Male', 4), ('Graphic Designer', 'Male', 5), ('Warehouse Associate', 'Female', 4), ('Warehouse Associate', 'Female', 5), ('Warehouse Associate', 'Male', 4), ('Warehouse Associate', 'Male', 5), ('Software Engineer', 'Female', 4), ('Software Engineer', 'Female', 5), ('Software Engineer', 'Male', 4), ('Software Engineer', 'Male', 5)]
# Level 4: [('Graphic Designer', 'Female', 4, 'Masters'), ('Graphic Designer', 'Female', 4, 'PhD'), ('Graphic Designer', 'Female', 4, 'College'), ('Graphic Designer', 'Female', 5, 'Masters'), ('Graphic Designer', 'Female', 5, 'PhD'), ('Graphic Designer', 'Female', 5, 'College'), ('Graphic Designer', 'Male', 4, 'Masters'), ('Graphic Designer', 'Male', 4, 'PhD'), ('Graphic Designer', 'Male', 4, 'College'), ('Graphic Designer', 'Male', 5, 'Masters'), ('Graphic Designer', 'Male', 5, 'PhD'), ('Graphic Designer', 'Male', 5, 'College'), ('Warehouse Associate', 'Female', 4, 'Masters'), ('Warehouse Associate', 'Female', 4, 'PhD'), ('Warehouse Associate', 'Female', 4, 'College'), ('Warehouse Associate', 'Female', 5, 'Masters'), ('Warehouse Associate', 'Female', 5, 'PhD'), ('Warehouse Associate', 'Female', 5, 'College'), ('Warehouse Associate', 'Male', 4, 'Masters'), ('Warehouse Associate', 'Male', 4, 'PhD'), ('Warehouse Associate', 'Male', 4, 'College'), ('Warehouse Associate', 'Male', 5, 'Masters'), ('Warehouse Associate', 'Male', 5, 'PhD'), ('Warehouse Associate', 'Male', 5, 'College'), ('Software Engineer', 'Female', 4, 'Masters'), ('Software Engineer', 'Female', 4, 'PhD'), ('Software Engineer', 'Female', 4, 'College'), ('Software Engineer', 'Female', 5, 'Masters'), ('Software Engineer', 'Female', 5, 'PhD'), ('Software Engineer', 'Female', 5, 'College'), ('Software Engineer', 'Male', 4, 'Masters'), ('Software Engineer', 'Male', 4, 'PhD'), ('Software Engineer', 'Male', 4, 'College'), ('Software Engineer', 'Male', 5, 'Masters'), ('Software Engineer', 'Male', 5, 'PhD'), ('Software Engineer', 'Male', 5, 'College')]
# Level 5: [('Graphic Designer', 'Female', 4, 'Masters', 'Management'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management'), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales'), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration'), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering'), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations'), ('Graphic Designer', 'Female', 4, 'College', 'Management'), ('Graphic Designer', 'Female', 4, 'College', 'Sales'), ('Graphic Designer', 'Female', 4, 'College', 'Administration'), ('Graphic Designer', 'Female', 4, 'College', 'Engineering'), ('Graphic Designer', 'Female', 4, 'College', 'Operations'), ('Graphic Designer', 'Female', 5, 'Masters', 'Management'), ('Graphic Designer', 'Female', 5, 'Masters', 'Sales'), ('Graphic Designer', 'Female', 5, 'Masters', 'Administration'), ('Graphic Designer', 'Female', 5, 'Masters', 'Engineering'), ('Graphic Designer', 'Female', 5, 'Masters', 'Operations'), ('Graphic Designer', 'Female', 5, 'PhD', 'Management'), ('Graphic Designer', 'Female', 5, 'PhD', 'Sales'), ('Graphic Designer', 'Female', 5, 'PhD', 'Administration'), ('Graphic Designer', 'Female', 5, 'PhD', 'Engineering'), ('Graphic Designer', 'Female', 5, 'PhD', 'Operations'), ('Graphic Designer', 'Female', 5, 'College', 'Management'), ('Graphic Designer', 'Female', 5, 'College', 'Sales'), ('Graphic Designer', 'Female', 5, 'College', 'Administration'), ('Graphic Designer', 'Female', 5, 'College', 'Engineering'), ('Graphic Designer', 'Female', 5, 'College', 'Operations'), ('Graphic Designer', 'Male', 4, 'Masters', 'Management'), ('Graphic Designer', 'Male', 4, 'Masters', 'Sales'), ('Graphic Designer', 'Male', 4, 'Masters', 'Administration'), ('Graphic Designer', 'Male', 4, 'Masters', 'Engineering'), ('Graphic Designer', 'Male', 4, 'Masters', 'Operations'), ('Graphic Designer', 'Male', 4, 'PhD', 'Management'), ('Graphic Designer', 'Male', 4, 'PhD', 'Sales'), ('Graphic Designer', 'Male', 4, 'PhD', 'Administration'), ('Graphic Designer', 'Male', 4, 'PhD', 'Engineering'), ('Graphic Designer', 'Male', 4, 'PhD', 'Operations'), ('Graphic Designer', 'Male', 4, 'College', 'Management'), ('Graphic Designer', 'Male', 4, 'College', 'Sales'), ('Graphic Designer', 'Male', 4, 'College', 'Administration'), ('Graphic Designer', 'Male', 4, 'College', 'Engineering'), ('Graphic Designer', 'Male', 4, 'College', 'Operations'), ('Graphic Designer', 'Male', 5, 'Masters', 'Management'), ('Graphic Designer', 'Male', 5, 'Masters', 'Sales'), ('Graphic Designer', 'Male', 5, 'Masters', 'Administration'), ('Graphic Designer', 'Male', 5, 'Masters', 'Engineering'), ('Graphic Designer', 'Male', 5, 'Masters', 'Operations'), ('Graphic Designer', 'Male', 5, 'PhD', 'Management'), ('Graphic Designer', 'Male', 5, 'PhD', 'Sales'), ('Graphic Designer', 'Male', 5, 'PhD', 'Administration'), ('Graphic Designer', 'Male', 5, 'PhD', 'Engineering'), ('Graphic Designer', 'Male', 5, 'PhD', 'Operations'), ('Graphic Designer', 'Male', 5, 'College', 'Management'), ('Graphic Designer', 'Male', 5, 'College', 'Sales'), ('Graphic Designer', 'Male', 5, 'College', 'Administration'), ('Graphic Designer', 'Male', 5, 'College', 'Engineering'), ('Graphic Designer', 'Male', 5, 'College', 'Operations'), ('Warehouse Associate', 'Female', 4, 'Masters', 'Management'), ('Warehouse Associate', 'Female', 4, 'Masters', 'Sales'), ('Warehouse Associate', 'Female', 4, 'Masters', 'Administration'), ('Warehouse Associate', 'Female', 4, 'Masters', 'Engineering'), ('Warehouse Associate', 'Female', 4, 'Masters', 'Operations'), ('Warehouse Associate', 'Female', 4, 'PhD', 'Management'), ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales'), ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration'), ('Warehouse Associate', 'Female', 4, 'P ...
# Level 6: [('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 5), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales', 2), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales', 5), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration', 2), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration', 5), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering', 2), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering', 5), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations', 2), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations', 5), ('Graphic Designer', 'Female', 4, 'College', 'Management', 2), ('Graphic Designer', 'Female', 4, 'College', 'Management', 5), ('Graphic Designer', 'Female', 4, 'College', 'Sales', 2), ('Graphic Designer', 'Female', 4, 'College', 'Sales', 5), ('Graphic Designer', 'Female', 4, 'College', 'Administration', 2), ('Graphic Designer', 'Female', 4, 'College', 'Administration', 5), ('Graphic Designer', 'Female', 4, 'College', 'Engineering', 2), ('Graphic Designer', 'Female', 4, 'College', 'Engineering', 5), ('Graphic Designer', 'Female', 4, 'College', 'Operations', 2), ('Graphic Designer', 'Female', 4, 'College', 'Operations', 5), ('Graphic Designer', 'Female', 5, 'Masters', 'Management', 2), ('Graphic Designer', 'Female', 5, 'Masters', 'Management', 4), ('Graphic Designer', 'Female', 5, 'Masters', 'Sales', 2), ('Graphic Designer', 'Female', 5, 'Masters', 'Sales', 4), ('Graphic Designer', 'Female', 5, 'Masters', 'Administration', 2), ('Graphic Designer', 'Female', 5, 'Masters', 'Administration', 4), ('Graphic Designer', 'Female', 5, 'Masters', 'Engineering', 2), ('Graphic Designer', 'Female', 5, 'Masters', 'Engineering', 4), ('Graphic Designer', 'Female', 5, 'Masters', 'Operations', 2), ('Graphic Designer', 'Female', 5, 'Masters', 'Operations', 4), ('Graphic Designer', 'Female', 5, 'PhD', 'Management', 2), ('Graphic Designer', 'Female', 5, 'PhD', 'Management', 4), ('Graphic Designer', 'Female', 5, 'PhD', 'Sales', 2), ('Graphic Designer', 'Female', 5, 'PhD', 'Sales', 4), ('Graphic Designer', 'Female', 5, 'PhD', 'Administration', 2), ('Graphic Designer', 'Female', 5, 'PhD', 'Administration', 4), ('Graphic Designer', 'Female', 5, 'PhD', 'Engineering', 2), ('Graphic Designer', 'Female', 5, 'PhD', 'Engineering', 4), ('Graphic Designer', 'Female', 5, 'PhD', 'Operations', 2), ('Graphic Designer', 'Female', 5, 'PhD', 'Operations', 4), ('Graphic Designer', 'Female', 5, 'College', 'Management', 2), ('Graphic Designer', 'Female', 5, 'College', 'Management', 4), ('Graphic Designer', 'Female', 5, 'College', 'Sales', 2), ('Graphic Designer', 'Female', 5, 'College', 'Sales', 4), ('Graphic Designer', 'Female', 5, 'College', 'Administration', 2), ('Graphic Designer', 'Female', 5, 'College', 'Administration', 4), ('Graphic Designer', 'Female', 5, 'College', 'Engineering', 2), ('Graphic Designer', 'Female', 5, 'College', 'Engineering', 4), ('Graphic Designer', 'Female', 5, 'College', 'Operations', 2), ('Graphic Designer', 'Female', 5, 'College', 'Operations', 4), ('Graphic Designer', 'Male', 4, 'Masters', 'Management', 2), ('Graphic Designer', 'Male', 4, 'Masters', 'Management', 5), ('Graphic Designer', 'Male', 4, 'Masters', 'Sales', 2), ('Graphic Designer', 'Male', 4, 'Masters', 'Sales', 5), ('Graphic Designer', 'Male', 4, 'Masters', 'Administrati ...
# Level 7: [('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Sales', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Administration', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Engineering', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'PhD', 'Operations', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'College', 'Management', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'College', 'Management', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'College', 'Management', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'College', 'Management', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'College', 'Sales', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'College', 'Sales', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'College', 'Sales', 5, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'College', 'Sales', 5, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'College', 'Administration', 2, '80,001-120,000'), ('Graphic Designer', 'Female', 4, 'College', 'Administration', 2, '40,000-80,000'), ('Graphic Designer', 'Female', 4, 'College', 'Administrat ...
# Level 8: [('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 2, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Management', 5, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 2, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Sales', 5, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 2, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Administration', 5, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 2, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Engineering', 5, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 2, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'Masters', 'Operations', 5, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2, '80,001-120,000', '20-39'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2, '80,001-120,000', '0-19'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2, '40,000-80,000', '20-39'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 2, '40,000-80,000', '0-19'), ('Graphic Designer', 'Female', 4, 'PhD', 'Management', 5, '80,001-120,000', '20-39'), ('Gr ...
