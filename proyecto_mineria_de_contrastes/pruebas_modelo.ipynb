# %% [markdown]
# Preprocesamiento de datos

# %%
### importacion de librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import itertools

from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# carga de datos

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('datasets/data.csv')

# %%
# Configura pandas para mostrar el contenido completo de las filas
pd.set_option('display.max_colwidth', None)

# %%
data = data.rename(columns={'jobTitle':'job_title',
                            'perfEval':'perf_eval',
                            'basePay':'base_pay'})

# %%
# creamos una columna nueva con el salario total

data['total_salary'] = data['base_pay'] + data['bonus']

# %%
# función que calcule la categoría de edad

def assing_age_range(age):
    if age < 0 or pd.isna(age):
        return 'NA'
    elif age < 20:
        return '0-19'
    elif age < 40:
        return '20-39'
    elif age < 60:
        return '40-59'
    elif age >= 60:
        return '60+'

# %%
# función que calcule la categoría de ingresos

def total_salary_range(salary):
    if salary < 40000 or pd.isna(salary):
        return '< 40,000'
    elif salary < 80001:
        return '40,000-80,000'
    elif salary < 120001:
        return '80,001-120,000'
    elif salary < 160001:
        return '120,001-160,000'
    elif salary >= 160001:
        return '> 160,000'

# %%
data['total_salary_range'] = data['total_salary'].apply(total_salary_range)
data['age_group'] = data['age'].apply(assing_age_range)

# %%
data.head()
# Out:
#              job_title  gender  age  perf_eval      edu            dept  \
# 0     Graphic Designer  Female   18          5  College      Operations
# 1    Software Engineer    Male   21          5  College      Management
# 2  Warehouse Associate  Female   19          4      PhD  Administration
# 3    Software Engineer    Male   20          5  Masters           Sales
# 4     Graphic Designer    Male   26          5  Masters     Engineering
#
#    seniority  base_pay  bonus  total_salary total_salary_range age_group
# 0          2     42363   9938         52301      40,000-80,000      0-19
# 1          5    108476  11128        119604     80,001-120,000     20-39
# 2          5     90208   9268         99476     80,001-120,000      0-19
# 3          4    108080  10154        118234     80,001-120,000     20-39
# 4          5     99464   9319        108783     80,001-120,000     20-39

# %%
testisng_df = (
    data
    .drop(columns={'age','base_pay','bonus','total_salary'})
)

# %%
testisng_df.head()
# Out:
#              job_title  gender  perf_eval      edu            dept  seniority  \
# 0     Graphic Designer  Female          5  College      Operations          2
# 1    Software Engineer    Male          5  College      Management          5
# 2  Warehouse Associate  Female          4      PhD  Administration          5
# 3    Software Engineer    Male          5  Masters           Sales          4
# 4     Graphic Designer    Male          5  Masters     Engineering          5
#
#   total_salary_range age_group
# 0      40,000-80,000      0-19
# 1     80,001-120,000     20-39
# 2     80,001-120,000      0-19
# 3     80,001-120,000     20-39
# 4     80,001-120,000     20-39

# %%
import pandas as pd
import numpy as np
import itertools

# Datos de entrada
data = {
    "job_title": ["Graphic Designer", "Software Engineer", "Warehouse Associate", "Software Engineer", "Graphic Designer"],
    "gender": ["Female", "Male", "Female", "Male", "Male"],
    "perf_eval": [5, 5, 4, 5, 5],
    "edu": ["College", "College", "PhD", "Masters", "Masters"],
    "dept": ["Operations", "Management", "Administration", "Sales", "Engineering"],
    "seniority": [2, 5, 5, 4, 5],
    "total_salary_range": ["40,000-80,000", "80,001-120,000", "80,001-120,000", "80,001-120,000", "80,001-120,000"],
    "age_group": ["0-19", "20-39", "0-19", "20-39", "20-39"]
}

df = pd.DataFrame(data)

def generate_contrast_sets(data, max_level):
    tree = {}
    columns = list(data.keys())
    classes_level_1 = list(set(data[columns[0]]))
    tree[1] = classes_level_1

    for level in range(2, max_level + 1):
        new_level_classes = []
        if level == 2:
            combinations = list(itertools.product(tree[1], set(data[columns[1]])))
        else:
            combinations = generate_combinations(tree[level - 1], set(data[columns[level - 1]]))

        for combination in combinations:
            new_classes = tuple(combination)
            if not any(set(c) == set(new_classes) for c in tree.values()):
                new_level_classes.append(new_classes)

        if new_level_classes:
            tree[level] = new_level_classes
        else:
            break

    return tree

def generate_combinations(previous_level, column_data):
    combinations = []
    for prev_class in previous_level:
        for column_value in column_data:
            new_combination = prev_class + (column_value,)
            if len(set(new_combination)) == len(new_combination):
                combinations.append(new_combination)
    return combinations

def calculate_support(contrast_sets, df, mindev):
    supports = {}
    for level, classes in contrast_sets.items():
        supports[level] = {}
        for c in classes:
            if type(c) == tuple:
                support = np.mean(df.apply(lambda row: all(item in row.values for item in c), axis=1))
            else:
                support = (df[df.columns[0]] == c).mean()
            if support >= mindev:
                supports[level][c] = support
    return supports

max_level = 8
mindev = 0.05

contrast_sets_tree = generate_contrast_sets(data, max_level)
supports = calculate_support(contrast_sets_tree, df, mindev)

for level, support in supports.items():
    if support:  # Si el nivel tiene soportes que cumplen con mindev
        print(f'Level {level}: {support}')
# Out:
# Level 1: {'Software Engineer': 0.4, 'Warehouse Associate': 0.2, 'Graphic Designer': 0.4}
# Level 2: {('Software Engineer', 'Male'): 0.4, ('Warehouse Associate', 'Female'): 0.2, ('Graphic Designer', 'Female'): 0.2, ('Graphic Designer', 'Male'): 0.2}
# Level 3: {('Software Engineer', 'Male', 4): 0.2, ('Software Engineer', 'Male', 5): 0.4, ('Warehouse Associate', 'Female', 4): 0.2, ('Warehouse Associate', 'Female', 5): 0.2, ('Graphic Designer', 'Female', 5): 0.2, ('Graphic Designer', 'Male', 5): 0.2}
# Level 4: {('Software Engineer', 'Male', 4, 'Masters'): 0.2, ('Software Engineer', 'Male', 5, 'College'): 0.2, ('Software Engineer', 'Male', 5, 'Masters'): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD'): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD'): 0.2, ('Graphic Designer', 'Female', 5, 'College'): 0.2, ('Graphic Designer', 'Male', 5, 'Masters'): 0.2}
# Level 5: {('Software Engineer', 'Male', 4, 'Masters', 'Sales'): 0.2, ('Software Engineer', 'Male', 5, 'College', 'Management'): 0.2, ('Software Engineer', 'Male', 5, 'Masters', 'Sales'): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration'): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration'): 0.2, ('Graphic Designer', 'Female', 5, 'College', 'Operations'): 0.2, ('Graphic Designer', 'Male', 5, 'Masters', 'Engineering'): 0.2}
# Level 6: {('Software Engineer', 'Male', 4, 'Masters', 'Sales', 5): 0.2, ('Software Engineer', 'Male', 5, 'Masters', 'Sales', 4): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 5): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration', 4): 0.2, ('Graphic Designer', 'Female', 5, 'College', 'Operations', 2): 0.2}
# Level 7: {('Software Engineer', 'Male', 4, 'Masters', 'Sales', 5, '80,001-120,000'): 0.2, ('Software Engineer', 'Male', 5, 'Masters', 'Sales', 4, '80,001-120,000'): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 5, '80,001-120,000'): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration', 4, '80,001-120,000'): 0.2, ('Graphic Designer', 'Female', 5, 'College', 'Operations', 2, '40,000-80,000'): 0.2}
# Level 8: {('Software Engineer', 'Male', 4, 'Masters', 'Sales', 5, '80,001-120,000', '20-39'): 0.2, ('Software Engineer', 'Male', 5, 'Masters', 'Sales', 4, '80,001-120,000', '20-39'): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 5, '80,001-120,000', '0-19'): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration', 4, '80,001-120,000', '0-19'): 0.2, ('Graphic Designer', 'Female', 5, 'College', 'Operations', 2, '40,000-80,000', '0-19'): 0.2}

# %%
# Datos de entrada
data = {
    "job_title": ["Graphic Designer", "Software Engineer", "Warehouse Associate", "Software Engineer", "Graphic Designer"],
    "gender": ["Female", "Male", "Female", "Male", "Male"],
    "perf_eval": [5, 5, 4, 5, 5],
    "edu": ["College", "College", "PhD", "Masters", "Masters"],
    "dept": ["Operations", "Management", "Administration", "Sales", "Engineering"],
    "seniority": [2, 5, 5, 4, 5],
    "total_salary_range": ["40,000-80,000", "80,001-120,000", "80,001-120,000", "80,001-120,000", "80,001-120,000"],
    "age_group": ["0-19", "20-39", "0-19", "20-39", "20-39"]
}

df = pd.DataFrame(testisng_df)

def generate_contrast_sets(data, max_level):
    tree = {}
    columns = list(data.keys())
    classes_level_1 = list(set(data[columns[0]]))
    tree[1] = classes_level_1

    for level in range(2, max_level + 1):
        new_level_classes = []
        if level == 2:
            combinations = list(itertools.product(tree[1], set(data[columns[1]])))
        else:
            combinations = generate_combinations(tree[level - 1], set(data[columns[level - 1]]))

        for combination in combinations:
            new_classes = tuple(combination)
            if not any(set(c) == set(new_classes) for c in tree.values()):
                new_level_classes.append(new_classes)

        if new_level_classes:
            tree[level] = new_level_classes
        else:
            break

    return tree

def generate_combinations(previous_level, column_data):
    combinations = []
    for prev_class in previous_level:
        for column_value in column_data:
            new_combination = prev_class + (column_value,)
            if len(set(new_combination)) == len(new_combination):
                combinations.append(new_combination)
    return combinations

def calculate_support(contrast_sets, df, mindev):
    supports = {}
    for level, classes in contrast_sets.items():
        supports[level] = {}
        for c in classes:
            if type(c) == tuple:
                support = np.mean(df.apply(lambda row: all(item in row.values for item in c), axis=1))
            else:
                support = (df[df.columns[0]] == c).mean()
            if support >= mindev:
                supports[level][c] = support
    return supports

max_level = 8
mindev = 0.05

contrast_sets_tree = generate_contrast_sets(data, max_level)
supports = calculate_support(contrast_sets_tree, df, mindev)

for level, support in supports.items():
    if support:  # Si el nivel tiene soportes que cumplen con mindev
        print(f'Level {level}: {support}')
# Out:
# Level 1: {'Warehouse Associate': 0.09, 'Software Engineer': 0.109, 'Graphic Designer': 0.098}
# Level 2: {('Software Engineer', 'Male'): 0.101, ('Graphic Designer', 'Male'): 0.05}
