# %% [markdown]
# Preprocesamiento de datos

# %%
### importacion de librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import itertools

from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# carga de datos

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('datasets/data.csv')

# %%
# Configura pandas para mostrar el contenido completo de las filas
pd.set_option('display.max_colwidth', None)

# %%
data = data.rename(columns={'jobTitle':'job_title',
                            'perfEval':'perf_eval',
                            'basePay':'base_pay'})

# %%
# creamos una columna nueva con el salario total

data['total_salary'] = data['base_pay'] + data['bonus']

# %%
# función que calcule la categoría de edad

def assing_age_range(age):
    if age < 0 or pd.isna(age):
        return 'NA'
    elif age < 20:
        return '0-19'
    elif age < 40:
        return '20-39'
    elif age < 60:
        return '40-59'
    elif age >= 60:
        return '60+'

# %%
# función que calcule la categoría de ingresos

def total_salary_range(salary):
    if salary < 40000 or pd.isna(salary):
        return '< 40,000'
    elif salary < 80001:
        return '40,000-80,000'
    elif salary < 120001:
        return '80,001-120,000'
    elif salary < 160001:
        return '120,001-160,000'
    elif salary >= 160001:
        return '> 160,000'

# %%
data['total_salary_range'] = data['total_salary'].apply(total_salary_range)
data['age_group'] = data['age'].apply(assing_age_range)

# %%
data.head()
# Out:
#              job_title  gender  age  perf_eval      edu            dept  \
# 0     Graphic Designer  Female   18          5  College      Operations
# 1    Software Engineer    Male   21          5  College      Management
# 2  Warehouse Associate  Female   19          4      PhD  Administration
# 3    Software Engineer    Male   20          5  Masters           Sales
# 4     Graphic Designer    Male   26          5  Masters     Engineering
#
#    seniority  base_pay  bonus  total_salary total_salary_range age_group
# 0          2     42363   9938         52301      40,000-80,000      0-19
# 1          5    108476  11128        119604     80,001-120,000     20-39
# 2          5     90208   9268         99476     80,001-120,000      0-19
# 3          4    108080  10154        118234     80,001-120,000     20-39
# 4          5     99464   9319        108783     80,001-120,000     20-39

# %%
testisng_df = (
    data
    .drop(columns={'age','base_pay','bonus','total_salary'})
)

# %%
import pandas as pd
import numpy as np
import itertools

# Datos de entrada
data = {
    "job_title": ["Graphic Designer", "Software Engineer", "Warehouse Associate", "Software Engineer", "Graphic Designer"],
    "gender": ["Female", "Male", "Female", "Male", "Male"],
    "perf_eval": [5, 5, 4, 5, 5],
    "edu": ["College", "College", "PhD", "Masters", "Masters"],
    "dept": ["Operations", "Management", "Administration", "Sales", "Engineering"],
    "seniority": [2, 5, 5, 4, 5],
    "total_salary_range": ["40,000-80,000", "80,001-120,000", "80,001-120,000", "80,001-120,000", "80,001-120,000"],
    "age_group": ["0-19", "20-39", "0-19", "20-39", "20-39"]
}

df = pd.DataFrame(data)

def generate_contrast_sets(data, max_level):
    tree = {}
    columns = list(data.keys())
    classes_level_1 = list(set(data[columns[0]]))
    tree[1] = classes_level_1

    for level in range(2, max_level + 1):
        new_level_classes = []
        if level == 2:
            combinations = list(itertools.product(tree[1], set(data[columns[1]])))
        else:
            combinations = generate_combinations(tree[level - 1], set(data[columns[level - 1]]))

        for combination in combinations:
            new_classes = tuple(combination)
            if not any(set(c) == set(new_classes) for c in tree.values()):
                new_level_classes.append(new_classes)

        if new_level_classes:
            tree[level] = new_level_classes
        else:
            break

    return tree

def generate_combinations(previous_level, column_data):
    combinations = []
    for prev_class in previous_level:
        for column_value in column_data:
            new_combination = prev_class + (column_value,)
            if len(set(new_combination)) == len(new_combination):
                combinations.append(new_combination)
    return combinations

def calculate_support(contrast_sets, df, mindev):
    supports = {}
    for level, classes in contrast_sets.items():
        supports[level] = {}
        for c in classes:
            if type(c) == tuple:
                support = np.mean(df.apply(lambda row: all(item in row.values for item in c), axis=1))
            else:
                support = (df[df.columns[0]] == c).mean()
            supports[level][c] = support
            
    # Seleccionar solo aquellos conjuntos de contraste cuyo soporte sea mayor o igual a mindev
    filtered_supports = {}
    for level, support_dict in supports.items():
        filtered_support_dict = {}
        for c, support in support_dict.items():
            if level + 1 in contrast_sets:  # Si existe el nivel de los hijos
                children_supports = [supports[level + 1][child_c] for child_c in contrast_sets[level + 1]]
                max_diff = np.max(np.abs(np.array(children_supports) - support))  # Calcular la máxima diferencia de soporte con los hijos
                if max_diff >= mindev:  # Si la máxima diferencia de soporte es mayor o igual a mindev
                    filtered_support_dict[c] = support
        if filtered_support_dict:  # Si el diccionario no está vacío
            filtered_supports[level] = filtered_support_dict

    return filtered_supports

max_level = 8
mindev = 0.1

contrast_sets_tree = generate_contrast_sets(data, max_level)
filtered_supports = calculate_support(contrast_sets_tree, df, mindev)

for level, support in filtered_supports.items():
    if support:  # Si el nivel tiene soportes que cumplen con mindev
        print(f'Level {level}: {support}')
# Out:
# Level 1: {'Warehouse Associate': 0.2, 'Graphic Designer': 0.4, 'Software Engineer': 0.4}
# Level 2: {('Warehouse Associate', 'Female'): 0.2, ('Warehouse Associate', 'Male'): 0.0, ('Graphic Designer', 'Female'): 0.2, ('Graphic Designer', 'Male'): 0.2, ('Software Engineer', 'Female'): 0.0, ('Software Engineer', 'Male'): 0.4}
# Level 3: {('Warehouse Associate', 'Female', 4): 0.2, ('Warehouse Associate', 'Female', 5): 0.2, ('Warehouse Associate', 'Male', 4): 0.0, ('Warehouse Associate', 'Male', 5): 0.0, ('Graphic Designer', 'Female', 4): 0.0, ('Graphic Designer', 'Female', 5): 0.2, ('Graphic Designer', 'Male', 4): 0.0, ('Graphic Designer', 'Male', 5): 0.2, ('Software Engineer', 'Female', 4): 0.0, ('Software Engineer', 'Female', 5): 0.0, ('Software Engineer', 'Male', 4): 0.2, ('Software Engineer', 'Male', 5): 0.4}
# Level 4: {('Warehouse Associate', 'Female', 4, 'PhD'): 0.2, ('Warehouse Associate', 'Female', 4, 'College'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters'): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD'): 0.2, ('Warehouse Associate', 'Female', 5, 'College'): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters'): 0.0, ('Warehouse Associate', 'Male', 4, 'PhD'): 0.0, ('Warehouse Associate', 'Male', 4, 'College'): 0.0, ('Warehouse Associate', 'Male', 4, 'Masters'): 0.0, ('Warehouse Associate', 'Male', 5, 'PhD'): 0.0, ('Warehouse Associate', 'Male', 5, 'College'): 0.0, ('Warehouse Associate', 'Male', 5, 'Masters'): 0.0, ('Graphic Designer', 'Female', 4, 'PhD'): 0.0, ('Graphic Designer', 'Female', 4, 'College'): 0.0, ('Graphic Designer', 'Female', 4, 'Masters'): 0.0, ('Graphic Designer', 'Female', 5, 'PhD'): 0.0, ('Graphic Designer', 'Female', 5, 'College'): 0.2, ('Graphic Designer', 'Female', 5, 'Masters'): 0.0, ('Graphic Designer', 'Male', 4, 'PhD'): 0.0, ('Graphic Designer', 'Male', 4, 'College'): 0.0, ('Graphic Designer', 'Male', 4, 'Masters'): 0.0, ('Graphic Designer', 'Male', 5, 'PhD'): 0.0, ('Graphic Designer', 'Male', 5, 'College'): 0.0, ('Graphic Designer', 'Male', 5, 'Masters'): 0.2, ('Software Engineer', 'Female', 4, 'PhD'): 0.0, ('Software Engineer', 'Female', 4, 'College'): 0.0, ('Software Engineer', 'Female', 4, 'Masters'): 0.0, ('Software Engineer', 'Female', 5, 'PhD'): 0.0, ('Software Engineer', 'Female', 5, 'College'): 0.0, ('Software Engineer', 'Female', 5, 'Masters'): 0.0, ('Software Engineer', 'Male', 4, 'PhD'): 0.0, ('Software Engineer', 'Male', 4, 'College'): 0.0, ('Software Engineer', 'Male', 4, 'Masters'): 0.2, ('Software Engineer', 'Male', 5, 'PhD'): 0.0, ('Software Engineer', 'Male', 5, 'College'): 0.2, ('Software Engineer', 'Male', 5, 'Masters'): 0.2}
# Level 5: {('Warehouse Associate', 'Female', 4, 'PhD', 'Management'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration'): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Sales'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Engineering'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Administration'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Operations'): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Management'): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Sales'): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Engineering'): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration'): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD', 'Operations'): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Management'): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Sales'): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Engineering'): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Administration'): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Operations'): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Management'): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Sales'): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Engineering'): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Administration'): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Operations'): 0.0, ('Warehouse Associate', 'Male', 4, 'PhD', 'Management'): 0.0, ('Warehouse Associate', 'Male', 4, 'PhD', 'Sales'): 0.0, ('Warehouse Associate', 'Male', 4, 'PhD', 'Engineering'): 0.0, ('Warehouse Associate', 'Male', 4, 'PhD', 'Administration'): 0.0, ('Warehouse Associate', 'Male', 4, 'PhD', 'Operations'): 0.0, ('Warehouse Associate', 'Male', 4, 'College', 'Management'): 0.0, ('Warehouse Associate', 'Male', 4, 'College', 'Sales'): 0.0, ('Warehouse Associate', 'Male', 4, 'College', 'Engineering'): 0.0, ('Warehouse Associate', 'Male', 4, 'College', 'Administration'): 0.0, ('Warehouse Associate', 'Male', 4, 'College', 'Operations'): 0.0, ('Warehouse Associate', 'Male', 4, 'Masters', 'Management'): 0.0, ('Warehouse Associate', 'Male', 4, 'Masters', 'Sales'): 0.0, ('Warehouse Associate', 'Male', 4, 'Masters', 'Engineering'): 0.0, ('Warehouse Associate', 'Male', 4, 'Masters', 'Administration'): 0.0, ('Warehouse Associate', 'Male', 4, 'Masters', 'Operations'): 0.0, ('Warehouse Associate', 'Male', 5, 'PhD', 'Management'): 0.0, ('Warehouse Associate', 'Male', 5, 'PhD', 'Sales'): 0.0, ('Warehouse Associate', 'Male', 5, 'PhD', 'Engineering'): 0.0, ('Warehouse Associate', 'Male', 5, 'PhD', 'Administration'): 0.0, ('Warehouse Associate', 'Male', 5, 'PhD', 'Operations'): 0.0, ('Warehouse Associate', 'Male', 5, 'College', 'Management'): 0.0, ('Warehouse Associate', 'Male', 5, 'College', 'Sales'): 0.0, ('Warehouse Associate', 'Male', 5, 'College', 'Engineering'): 0.0, ('Warehouse Associate', 'Male', 5, 'College', 'Administration'): 0.0, ('Warehouse Associate', 'Male', 5, 'College', 'Operations'): 0.0, ('Warehouse Associate', 'Male', 5, 'Masters', 'Management'): 0.0, ('Warehouse Associate', 'Male', 5, 'Masters', 'Sales'): 0.0, ('Warehouse Associate', 'Male', 5, 'Masters', 'Engineering'): 0.0, ('Warehouse Associate', 'Male', 5, 'Masters', 'Administration'): 0.0, ('Warehouse Associate', 'Male', 5, 'Masters', 'Operations'): 0.0, ('Graphic Designer', 'Female', 4, 'PhD', 'Manageme ...
# Level 6: {('Warehouse Associate', 'Female', 4, 'PhD', 'Management', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Management', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 5): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Sales', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Sales', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Engineering', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Engineering', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Administration', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Administration', 5): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Operations', 2): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Operations', 5): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Management', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Management', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Sales', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Sales', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Engineering', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Engineering', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Administration', 4): 0.2, ('Warehouse Associate', 'Female', 5, 'PhD', 'Operations', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'PhD', 'Operations', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Management', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Management', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Sales', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Sales', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Engineering', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Engineering', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Administration', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Administration', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Operations', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'College', 'Operations', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Management', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Management', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Sales', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Sales', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Engineering', 2): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Engineering', 4): 0.0, ('Warehouse Associate', 'Female', 5, 'Masters', 'Administration', 2): 0.0, ('Warehouse Associate', 'Fe ...
# Level 7: {('Warehouse Associate', 'Female', 4, 'PhD', 'Management', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Management', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Management', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Management', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Sales', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Engineering', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Administration', 5, '80,001-120,000'): 0.2, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'PhD', 'Operations', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Management', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Sales', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Engineering', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Administration', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'College', 'Operations', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management', 2, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management', 5, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Management', 5, '80,001-120,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Sales', 2, '40,000-80,000'): 0.0, ('Warehouse Associate', 'Female', 4, 'Masters', 'Sales', 2, '80,001-120,000'): 0.0, ('Warehou ...

# %%
# Generar tabla de resumen
summary_table = []
for level, support in filtered_supports.items():
    for cand, sup in support.items():
        dev = sup - mindev
        surp = abs(dev)
        summary_table.append([level, cand, dev, surp])

# Convertir a DataFrame de pandas y mostrar
summary_df = pd.DataFrame(summary_table, columns=["Level", "Cand.", "Dev.", "Surp."])

# Agregamos los valores por cada nivel y mostramos los resultados
summary_df_agg = summary_df.groupby('Level').agg({'Cand.': 'count', 'Dev.': 'sum', 'Surp.': 'sum'}).reset_index()
summary_df_agg.loc['total'] = summary_df_agg.sum()
summary_df_agg['Level'].iloc[-1] = 'total'
print(summary_df_agg)
# Out:
#        Level   Cand.   Dev.  Surp.
# 0        1.0     3.0    0.7    0.7
# 1        2.0     6.0    0.4    0.8
# 2        3.0    12.0    0.2    1.4
# 3        4.0    36.0   -2.2    3.6
# 4        5.0   180.0  -16.6   18.0
# 5        6.0   360.0  -35.0   36.0
# 6        7.0   720.0  -71.0   72.0
# total  total  1317.0 -123.5  132.5

# %%
import pandas as pd
import numpy as np
import itertools
from scipy.stats import chisquare

# Datos de entrada
data = {
    "job_title": ["Graphic Designer", "Software Engineer", "Warehouse Associate", "Software Engineer", "Graphic Designer"],
    "gender": ["Female", "Male", "Female", "Male", "Male"],
    "perf_eval": [5, 5, 4, 5, 5],
    "edu": ["College", "College", "PhD", "Masters", "Masters"],
    "dept": ["Operations", "Management", "Administration", "Sales", "Engineering"],
    "seniority": [2, 5, 5, 4, 5],
    "total_salary_range": ["40,000-80,000", "80,001-120,000", "80,001-120,000", "80,001-120,000", "80,001-120,000"],
    "age_group": ["0-19", "20-39", "0-19", "20-39", "20-39"]
}

df = pd.DataFrame(data)

def generate_contrast_sets(data, max_level):
    tree = {}
    columns = list(data.keys())
    classes_level_1 = list(set(data[columns[0]]))
    tree[1] = classes_level_1

    for level in range(2, max_level + 1):
        new_level_classes = []
        if level == 2:
            combinations = list(itertools.product(tree[1], set(data[columns[1]])))
        else:
            combinations = generate_combinations(tree[level - 1], set(data[columns[level - 1]]))

        for combination in combinations:
            new_classes = tuple(combination)
            if not any(set(c) == set(new_classes) for c in tree.values()):
                new_level_classes.append(new_classes)

        if new_level_classes:
            tree[level] = new_level_classes
        else:
            break

    return tree

def generate_combinations(previous_level, column_data):
    combinations = []
    for prev_class in previous_level:
        for column_value in column_data:
            new_combination = prev_class + (column_value,)
            if len(set(new_combination)) == len(new_combination):
                combinations.append(new_combination)
    return combinations

def calculate_support(contrast_sets, df, mindev, alpha=0.05):
    supports = {}
    for level, classes in contrast_sets.items():
        supports[level] = {}
        for c in classes:
            if type(c) == tuple:
                support = np.mean(df.apply(lambda row: all(item in row.values for item in c), axis=1))
            else:
                support = (df[df.columns[0]] == c).mean()
            supports[level][c] = support

    filtered_supports = {}
    for level, support_dict in supports.items():
        filtered_support_dict = {}
        for c, support in support_dict.items():
            if level + 1 in contrast_sets:
                children_supports = [supports[level + 1][child_c] for child_c in contrast_sets[level + 1] if child_c in supports[level + 1]]
                max_diff = np.max(np.abs(np.array(children_supports) - support))

                # Round the observed and expected frequencies
                obs_freq = np.around(children_supports, decimals=6)
                exp_freq = np.around([support]*len(children_supports), decimals=6)

                # Perform chi-square test
                chi2, p = chisquare(obs_freq, f_exp=exp_freq)

                if p <= alpha:
                    filtered_support_dict[c] = support

        if filtered_support_dict:
            filtered_supports[level] = filtered_support_dict

    return filtered_supports

max_level = 8
mindev = 0.1

contrast_sets_tree = generate_contrast_sets(data, max_level)
filtered_supports = calculate_support(contrast_sets_tree, df, mindev)

for level, support in filtered_supports.items():
    if support:
        print(f'Level {level}: {support}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb Cell 14 in 9
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=88'>89</a> mindev = 0.1
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=90'>91</a> contrast_sets_tree = generate_contrast_sets(data, max_level)
# ---> <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=91'>92</a> filtered_supports = calculate_support(contrast_sets_tree, df, mindev)
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=93'>94</a> for level, support in filtered_supports.items():
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=94'>95</a>     if support:
#
# /Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb Cell 14 in 7
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=74'>75</a> exp_freq = np.around([support]*len(children_supports), decimals=6)
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=76'>77</a> # Perform chi-square test
# ---> <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=77'>78</a> chi2, p = chisquare(obs_freq, f_exp=exp_freq)
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=79'>80</a> if p <= alpha:
#      <a href='vscode-notebook-cell:/Users/marinzavala/Library/CloudStorage/OneDrive-Personal/PERSONAL%20MARIN/GIT/MCS/proyecto_mineria_de_contrastes/pruebas_modelo.ipynb#Y111sZmlsZQ%3D%3D?line=80'>81</a>     filtered_support_dict[c] = support
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:7558, in chisquare(f_obs, f_exp, ddof, axis)
#    7433 def chisquare(f_obs, f_exp=None, ddof=0, axis=0):
#    7434     """Calculate a one-way chi-square test.
#    7435
#    7436     The chi-square test tests the null hypothesis that the categorical data
#    (...)
#    7556
#    7557     """
# -> 7558     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    7559                             lambda_="pearson")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:7399, in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    7393     if diff_gt_tol:
#    7394         msg = (f"For each axis slice, the sum of the observed "
#    7395                f"frequencies must agree with the sum of the "
#    7396                f"expected frequencies to a relative tolerance "
#    7397                f"of {rtol}, but the percent differences are:\n"
#    7398                f"{relative_diff}")
# -> 7399         raise ValueError(msg)
#    7401 else:
#    7402     # Ignore 'invalid' errors so the edge case of a data set with length 0
#    7403     # is handled without spurious warnings.
#    7404     with np.errstate(invalid='ignore'):
#
# ValueError: For each axis slice, the sum of the observed frequencies must agree with the sum of the expected frequencies to a relative tolerance of 1e-08, but the percent differences are:
# 0.19999999999999996
